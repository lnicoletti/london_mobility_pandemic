# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")

date = "0222"

df = pd.read_csv(f'../data/raw/Global_Mobility_Report_{date}.csv')
df_pp = pd.read_csv('../data/raw/pp-2020.csv', header=None)
covid = pd.read_csv(f'../data/raw/phe_cases_london_boroughs_{date}.csv')
admin = gpd.read_file('../data/raw/London_Borough_Excluding_MHW.shp')
income = pd.read_excel('../data/raw/gla-household-income-estimates.xlsx', sheet_name="Boroughs", header = 2)
ethnicity = pd.read_excel('../data/raw/ethnic-groups-by-borough.xls', sheet_name="2018", header = 1)
income_uk = pd.read_excel('../data/raw/incomeestimatesforsmallareasdatasetfinancialyearending20181.xls', sheet_name="Total annual income", header = 4)

# %% [markdown]
# ## 1) Explore trends

# %%
covid_day_gl = covid[['date', 'new_cases', 'total_cases']] #.groupby('date').sum().reset_index()
covid_day_gl['days_since_first_case'] = range(len(covid_day_gl))

# %%
covid_day_gl['date'] = pd.to_datetime(covid_day_gl['date'])
fig, ax = plt.subplots(figsize = (15,10))
sns.lineplot(data=covid_day_gl.groupby('date').agg({"new_cases": "sum", "total_cases": "max"}).reset_index().iloc[:-2,:], x="date", y="new_cases", ax=ax)
# sns.barplot(data=covid_day_gl, x="days_since_first_case", y = 'new_cases', ax=ax)
# sns.barplot(data=covid_day_gl, x="date", y="new_cases", ax=ax)

# %%
covid_day_gl.groupby('date').agg({"new_cases": "sum", "total_cases": "max"}).reset_index().iloc[:-2,:].to_csv(f'../data/processed_final/london_covid_time_{date}.csv')

# %%
# df[df['country_region'] == "Italy"].sub_region_2.unique()

# %%
# df[df['sub_region_1']== "South Holland"].sub_region_2.unique()

# %%
# df[df['sub_region_1']== "South Holland"].sub_region_2.unique()

Cardiff
Glasgow City
Birmingham District

# %%
df_cd = df[df['sub_region_1']=='Cardiff']
df_cd = df_cd.dropna(subset=['sub_region_1'])

# %%
# make datetime + drop day of week
df['date'] = pd.to_datetime(df['date'])
df = df[df.date.dt.dayofweek < 5]
# make dfs for cities of interest

df_cd = df[df['sub_region_1']=='Cardiff']
df_cd = df_cd.dropna(subset=['sub_region_1'])

df_gl = df[df['sub_region_1']=='Greater London']
df_gl = df_gl.dropna(subset=['sub_region_2'])

df_bm = df[df['sub_region_2']=='Birmingham District']
df_bm = df_bm.dropna(subset=['sub_region_2'])
df_bm['city'] = 'Birmingham'

df_gg = df[df['sub_region_1']=='Glasgow City']
df_gg = df_gg.dropna(subset=['sub_region_1'])
df_gg['city'] = 'Glasgow'

df_cd = df[df['sub_region_1']=='Cardiff']
df_cd = df_cd.dropna(subset=['sub_region_1'])
df_cd['city'] = 'Cardiff'

df_nyc = df[df['sub_region_2'].isin(['Bronx County', 'Queens County', 'New York County', 'Rockland County', 'Westchester County', 'Dutchess County'])]

df_la = df[df['sub_region_2'].isin(['Los Angeles County'])]
df_la['city'] = 'Los Angeles'

df_sf = df[df['sub_region_2'].isin(['San Francisco County'])]
df_sf['city'] = 'San Francisco'

df_ps = df[df['sub_region_2'].isin(['Paris'])]
df_ps['city'] = 'Paris'

df_ml = df[df['sub_region_2'].isin(['Metropolitan City of Milan'])]
df_ml['city'] = 'Milan'

df_se = df[df['metro_area'].isin(['Seoul Metropolitan Area'])]
df_se['city'] = 'Seoul'

df_hk = df[df['country_region'].isin(['Hong Kong'])]
df_hk['city'] = 'Hong Kong'

df_ak = df[df['sub_region_1'].isin(['Auckland'])]
df_ak['city'] = 'Auckland'

df_sd = df[df['sub_region_2'].isin(['Council of the City of Sydney'])]
df_sd['city'] = 'Sydney'

# %%
df_gl_c = df_gl.groupby('date').mean().reset_index().drop('census_fips_code', axis=1)
df_gl_c['city'] = 'Greater London'
df_nyc_c = df_nyc.groupby('date').mean().reset_index().drop('census_fips_code', axis=1)
df_nyc_c['city'] = 'New York City'

# %%
index = ['date', 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 
       'parks_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline', 'city']

cities = pd.concat([df_gl_c[index], df_cd[index], df_gg[index], df_bm[index], df_nyc_c[index], df_ps[index], df_ml[index], df_se[index], df_hk[index], df_ak[index], df_la[index], df_sf[index], df_sd[index]]).reset_index().drop('index', axis=1)
cities['tot_mobility'] = (cities['retail_and_recreation_percent_change_from_baseline'] + cities['grocery_and_pharmacy_percent_change_from_baseline'] + cities['transit_stations_percent_change_from_baseline'] + cities['workplaces_percent_change_from_baseline'])/4
cities['date'] = pd.to_datetime(cities['date'])
cities.to_csv(f'../data/processed_final/cities_mob_{date}.csv')

# %%
fig, ax = plt.subplots(figsize = (15,10))
sns.lineplot(data=df_gl, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='blue')
sns.lineplot(data=df_cd, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='red')
sns.lineplot(data=df_gg, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='green')
sns.lineplot(data=df_bm, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='orange')
# sns.lineplot(data=df_se, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='orange')

# sns.lineplot(data=df_se, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax)
ax.axhline(0, ls='--')
plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fig, ax = plt.subplots(figsize = (15,10))
sns.lineplot(data=df_gl, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, color='blue')
sns.lineplot(data=df_gl, x="date", y="grocery_and_pharmacy_percent_change_from_baseline", ax=ax, color='orange')
sns.lineplot(data=df_gl, x="date", y="transit_stations_percent_change_from_baseline", ax=ax, color='black')
# sns.lineplot(data=df_gl, x="date", y="workplaces_percent_change_from_baseline", ax=ax, color='green')
# sns.lineplot(data=df_gl, x="date", y="residential_percent_change_from_baseline", ax=ax)
ax.axhline(0, ls='--')
plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fig, ax = plt.subplots(figsize = (15,10))
# sns.lineplot(data=df_gl, x="date", y="parks_percent_change_from_baseline", ax=ax, color='green')
sns.lineplot(data=df_gl, x="date", y="residential_percent_change_from_baseline", ax=ax, color='red')
sns.lineplot(data=df_gl, x="date", y="workplaces_percent_change_from_baseline", ax=ax, color='green')

ax.axhline(0, ls='--')
plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# import plotly.express as px
# fig = px.line(df_gl, x="date", 
#                  y="retail_and_recreation_percent_change_from_baseline", 
#                   height=1200)
# fig.add_trace(px.line(df_nyc, x="date", 
#                  y="retail_and_recreation_percent_change_from_baseline", 
#                  height=1200))
# # fig.add_hline(y=0, line_dash="dot",
# #               annotation_text="pre-COVID19 baseline",
# #               annotation_position="bottom right")

# fig.show()

# %%
# fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
#                  y="retail_and_recreation_percent_change_from_baseline", 
#                  color="sub_region_2")
# fig.show()

# %%
# fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
#                  y="transit_stations_percent_change_from_baseline", 
#                  color="sub_region_2")
# fig.show()

# %%
# fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
#                  y="workplaces_percent_change_from_baseline", 
#                  color="sub_region_2")
# fig.show()

# %%
# fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
#                  y="grocery_and_pharmacy_percent_change_from_baseline", 
#                  color="sub_region_2")
# fig.show()

# %%
# import plotly.express as px
# fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
#                  y="retail_and_recreation_percent_change_from_baseline", 
#                  facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# # fig.add_hline(y=0, line_dash="dot",
# #               annotation_text="pre-COVID19 baseline",
# #               annotation_position="bottom right")

# fig.show()

# %%
import plotly.express as px
fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
                 y="grocery_and_pharmacy_percent_change_from_baseline", 
                 facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# fig.add_hline(y=0, line_dash="dot",
#               annotation_text="pre-COVID19 baseline",
#               annotation_position="bottom right")

fig.show()

# %%
import plotly.express as px
fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
                 y="workplaces_percent_change_from_baseline", 
                 facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# fig.add_hline(y=0, line_dash="dot",
#               annotation_text="pre-COVID19 baseline",
#               annotation_position="bottom right")

fig.show()

# %%
import plotly.express as px
fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
                 y="residential_percent_change_from_baseline", 
                 facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# fig.add_hline(y=0, line_dash="dot",
#               annotation_text="pre-COVID19 baseline",
#               annotation_position="bottom right")

fig.show()

# %%
import plotly.express as px
fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
                 y="transit_stations_percent_change_from_baseline", 
                 facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# fig.add_hline(y=0, line_dash="dot",
#               annotation_text="pre-COVID19 baseline",
#               annotation_position="bottom right")

fig.show()

# %%
import plotly.express as px
fig = px.line(df_gl[df_gl['sub_region_2'].isna()==False], x="date", 
                 y="parks_percent_change_from_baseline", 
                 facet_col="sub_region_2", facet_col_wrap=5, height=1200)

# fig.add_hline(y=0, line_dash="dot",
#               annotation_text="pre-COVID19 baseline",
#               annotation_position="bottom right")

fig.show()

# %% [markdown]
# ## 2) Analysis by Borough

# %%
# make data for city of london and total cases per layer
covid_tot = covid.tail(32)[['area_name','total_cases', 'area_code']]
covid_tot = covid_tot.append(pd.DataFrame([['City of London', 104, 'E09000001']], columns=covid_tot.columns)).sort_values('area_code').reset_index().drop('index',axis=1)
covid_tot['area_name'] = covid_tot['area_name'].replace({'Hackney and City of London': 'Hackney'})
covid_tot['total_cases'][covid_tot['area_name']=='Hackney'] = covid_tot['total_cases'][covid_tot['area_name']=='Hackney'].values - covid_tot['total_cases'][covid_tot['area_name']=='City of London'].values
covid_tot.to_csv(f'../data/processed_final/london_covid_tot_{date}.csv')

# %%
# names must match
admin.NAME = admin.NAME.str.replace('Westminster', 'City of Westminster')
df_gl['sub_region_2'] = df_gl['sub_region_2'].str.replace('London Borough of ', '').str.replace('Royal Borough of ', '')
df_gl['sub_region_2'][df_gl['sub_region_2'] == 'City of Westminster'] = 'Westminster'
# df_gl = pd.merge(admin[['NAME', 'geometry']], df_gl, left_on='NAME', right_on='sub_region_2')

# %%
# mobility by borough
df_gl = df_gl.drop(['country_region_code', 'country_region', 'sub_region_1', 'metro_area', 'iso_3166_2_code', 'census_fips_code'], axis = 1)
df_gl = pd.merge(df_gl, covid_tot, left_on='sub_region_2', right_on='area_name').drop('sub_region_2', axis=1)
# df_gl

# %%
import numpy as np
from functools import reduce
df_gl['tot_mobility'] = (df_gl['retail_and_recreation_percent_change_from_baseline'] + df_gl['grocery_and_pharmacy_percent_change_from_baseline'] + df_gl['transit_stations_percent_change_from_baseline'] + df_gl['workplaces_percent_change_from_baseline'])/4

# %%
# without demographics
df_gl.to_csv(f'../data/processed_final/london_mobility_boroughs_agg_{date}.csv')

# %% [markdown]
# ### 2.1) Analysis by Borough for ALL of UK
# #### 2.1.1) Time Series

# %%
index = ['date', 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 
       'parks_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline', 'residential_percent_change_from_baseline', 'city', 'borough']

# %%
df_uk = df[(df['country_region']=='United Kingdom')&(df['sub_region_2'].isna()==False)]
df_uk = df_uk.rename(columns = {"sub_region_1": "city", "sub_region_2": "borough"})
df_uk = df_uk[index]

# %%
# df_uk['borough'].unique()

# %%
index_income = ['Local authority name', 'Total annual income (£)']
income_uk = income_uk[index_income].groupby('Local authority name').median().reset_index()

# %%
income_uk.quantile(.25)
# Out:
# Total annual income (£)    37700.0
# Name: 0.25, dtype: float64

# %%
income_uk['income_status'] = ""
income_uk['income_status'][income_uk['Total annual income (£)']>=48000] = "High Income"
# income_uk['income_status'][income_uk['Total annual income (£)']>=57000] = "Very High Income"
income_uk['income_status'][(income_uk['Total annual income (£)']>37000)&(income_uk['Total annual income (£)']<48000)] = "Mid Income"
income_uk['income_status'][income_uk['Total annual income (£)']<=37000] = "Low Income"
# income_uk['income_status'][income_uk['Total annual income (£)']<=33000] = "Very Low Income"

# %%
df_uk['borough_abbr'] = df_uk['borough'].str.replace('London Borough of ', '').str.replace('Royal Borough of ', '').str.replace(' District', '')

# %%
income_uk['Local authority name'].unique()

# %%
df_demo_uk = pd.merge(income_uk, df_uk, left_on=['Local authority name'], right_on=['borough_abbr'],
                                            how='inner')

# %%
df_demo_uk['tot_mobility'] = (df_demo_uk['retail_and_recreation_percent_change_from_baseline'] + df_demo_uk['grocery_and_pharmacy_percent_change_from_baseline'] + df_demo_uk['transit_stations_percent_change_from_baseline'] + df_demo_uk['workplaces_percent_change_from_baseline'])/4

# %%
df_uk_dMean = df_demo_uk[df_demo_uk['income_status']!="Mid Income"].groupby(['income_status', 'date']).mean().reset_index()
df_uk_dMean['borough_abbr'] = ""
df_uk_dMean['borough_abbr'][df_uk_dMean['income_status']=="High Income"] = "Mean Value HI"
df_uk_dMean['borough_abbr'][df_uk_dMean['income_status']=="Low Income"] = "Mean Value LI"
# df_uk_dMean['borough_abbr'][df_uk_dMean['income_status']!="Very Low Income"] = "Mean Value VLI"
# df_uk_dMean['borough_abbr'][df_uk_dMean['income_status']!="Very High Income"] = "Mean Value VHI"
df_uk_final = pd.concat([df_demo_uk, df_uk_dMean])

# %%
fig, ax = plt.subplots(figsize = (15,10))
sns.lineplot(data=df_uk_dMean, x="date", y="retail_and_recreation_percent_change_from_baseline", ax=ax, hue='income_status')
# sns.lineplot(data=df_uk_dMean, x="date", y="grocery_and_pharmacy_percent_change_from_baseline", ax=ax, color='orange')
# sns.lineplot(data=df_gl, x="date", y="workplaces_percent_change_from_baseline", ax=ax, color='green')
# sns.lineplot(data=df_gl, x="date", y="residential_percent_change_from_baseline", ax=ax)
ax.axhline(0, ls='--')
plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df_uk_final.to_csv(f'../data/processed_final/uk_mobility_boroughs_demographics_agg_{date}.csv')

# %% [markdown]
# #### 2.1.1) Scatter Plot

# %%
# df_uk_final.borough_abbr.unique()

# %%
# income_uk['Local authority name'].unique()

# %%
mob_inc_bo = df_uk_final.groupby(['borough_abbr', "income_status", "city"]).mean().reset_index()

# %%
ax = sns.scatterplot(data = mob_inc_bo[mob_inc_bo['tot_mobility']>-60], x='tot_mobility', y='Total annual income (£)')
# plt.gca().invert_yaxis()
# plt.gca().invert_yaxis()

# %%
sns.scatterplot(data = mob_inc_bo[mob_inc_bo['tot_mobility']>-60], x='workplaces_percent_change_from_baseline', y='Total annual income (£)')

# %%
sns.scatterplot(data = mob_inc_bo[mob_inc_bo['tot_mobility']>-60], x='Total annual income (£)', y='residential_percent_change_from_baseline')

# %%
sns.scatterplot(data = mob_inc_bo[mob_inc_bo['retail_and_recreation_percent_change_from_baseline']>-60], x='retail_and_recreation_percent_change_from_baseline', y='Total annual income (£)')

# %%
mob_inc_bo.to_csv(f'../data/processed_final/uk_mobility_boroughs_vs_income_{date}.csv')

# %% [markdown]
# ## 3) Analysis by demographic and income

# %%
import numpy as np

# %%
income = income.iloc[:33,:][['Code', 'Unnamed: 26']].rename(columns = {"Code": "area_code", "Unnamed: 26":"income"})
ethnicity = ethnicity.iloc[:33,:7].drop("Unnamed: 1", axis=1).rename(columns = {"Unnamed: 0": "area_code"}).replace('-', np.NaN)

# %%
ethnicity['White'] = ethnicity['White']/ethnicity['Total']
ethnicity['Asian'] = ethnicity['Asian']/ethnicity['Total']
ethnicity['Black'] = ethnicity['Black']/ethnicity['Total']
ethnicity['Mixed/ Other'] = ethnicity['Mixed/ Other']/ethnicity['Total']

# %%
ethnicity.quantile(.25)
# Out:
# White                0.507211
# Asian                0.074642
# Black                0.070302
# Mixed/ Other         0.069051
# Total           235000.000000
# Name: 0.25, dtype: float64

# %%
ethnicity['ethnic_majority'] = np.NaN
ethnicity['ethnic_majority'][ethnicity['White']>0.66] = "White"
ethnicity['ethnic_majority'][ethnicity['White']<0.51] = "Ethnic Minority"
ethnicity['ethnic_majority'][ethnicity['area_code']=="E09000001"] = np.NaN
# income['ethnic_majority'][(income['income']>36000)&(income['income']<43000)] = "Mid Income"
# income['ethnic_majority'][income['income']<=36000] = "Low Income"
# income['ethnic_majority'][income['income']<=36000] = "Low Income"

# %%
income['income_status'] = ""
income['income_status'][income['income']>=43000] = "High Income"
income['income_status'][(income['income']>36000)&(income['income']<43000)] = "Mid Income"
income['income_status'][income['income']<=36000] = "Low Income"

# %%
dfs = [df_gl, income, ethnicity]
df_gl_demo = reduce(lambda  left, right: pd.merge(left, right, on=['area_code'],
                                            how='inner'), dfs)

# %%
# df_gl_demo.to_csv('../data/processed_final/london_mobility_boroughs_demographics.csv')
# df_gl_demo.to_csv('../data/processed_final/london_mobility_boroughs_demographics.csv')

# %%
# df_gl_demo[df_gl_demo['income_status']!="Mid Income"].groupby(['income_status', 'date']).mean().reset_index().to_csv('../data/london_mobility_boroughs_demographics_agg.csv')

# %%
# get mean values for income
df_gl_dMean = df_gl_demo[df_gl_demo['income_status']!="Mid Income"].groupby(['income_status', 'date']).mean().reset_index()
df_gl_dMean['area_code'] = ""
df_gl_dMean['area_code'][df_gl_dMean['income_status']=="High Income"] = "Mean Value HI"
df_gl_dMean['area_code'][df_gl_dMean['income_status']=="Low Income"] = "Mean Value LI"
# get mean values for ethnicity
df_gl_eMean = df_gl_demo.groupby(['ethnic_majority', 'date']).mean().reset_index()
df_gl_eMean['area_code'] = ""
df_gl_eMean['area_code'][df_gl_eMean['ethnic_majority']=="White"] = "Mean Value W"
df_gl_eMean['area_code'][df_gl_eMean['ethnic_majority']=="Ethnic Minority"] = "Mean Value EM"


df_gl_final = pd.concat([df_gl_demo, df_gl_dMean, df_gl_eMean])

# %%
# with demographics
df_gl_final.to_csv(f'../data/processed_final/london_mobility_boroughs_demographics_agg_{date}.csv')

# %%
sns.lineplot(data = df_gl_final[df_gl_final['area_code'].isin(["Mean Value LI", "Mean Value HI"])][['tot_mobility', 'income_status', 'date', 'area_code']], 
             x='date', y='tot_mobility', hue = 'area_code')

# %%
sns.lineplot(data = df_gl_final[df_gl_final['area_code'].isin(["Mean Value W", "Mean Value EM"])][['tot_mobility', 'income_status', 'date', 'area_code']], 
             x='date', y='tot_mobility', hue = 'area_code')

# %% [markdown]
# #### 3.1 Scatter Plot

# %%
mob_e_bo = df_gl_final.groupby(['area_name']).mean().reset_index()

# %%
sns.scatterplot(data = mob_e_bo, x='workplaces_percent_change_from_baseline', y='White')

# %%
mob_e_bo.to_csv(f'../data/processed_final/uk_mobility_boroughs_vs_ethnicity_{date}.csv')

# %%
# df_gl.plot(column='retail_and_recreation_percent_change_from_baseline', cmap='Reds_r', edgecolor='white', linewidth=0.2)

# %%
# admin.NAME.unique()

# %%
# df_gl.sub_region_2.unique()

# %%
# df_gl[df_gl['date']=='2020-08-17'].plot(column='retail_and_recreation_percent_change_from_baseline', cmap='Reds_r', edgecolor='white', linewidth=0.2)

# %%
# pd.DataFrame('City of London', 'E09000012', 7, 8], columns = covid.columns)
# # covid.area_name['City of London'] =

# %%
# admin[admin['NAME'].isin(['City of London', 'Hackney'])].plot()

# %%
# sorted(covid_tot.area_name.unique())

# %%
len(sorted(df_gl.area_code.unique()))
# Out:
# 33

# %%
pd.pivot_table(df_gl[['date', 'area_code', 'tot_mobility']], values='tot_mobility', index=['area_code'],
                    columns=['date']).reset_index().to_csv('../data/london_mobility_boroughs.csv')

# %%
# covid_tot.to_csv('../data/london_covid_tot.csv')
df_gl_c.to_csv('../data/london_mobility_boroughs.csv')

# %%
df_gl_c = df_gl[['date', 'area_code', 'area_name', 'tot_mobility']].fillna(method = 'ffill')

# %% [markdown]
# ## 3) Real Estate

# %%
df_pp_gl = df_pp[df_pp[13]=='GREATER LONDON']
df_pp_gl.columns = ['ID', 'price_paid', 'date', 'post_code', 'D', 'N', 'F', 'street_n', 'unknown', 'street', 'locality', 'city', 'district', 'county', 'A', 'B']

# %%
df_pp_gl['date'] = pd.to_datetime(df_pp_gl['date'])
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pp_gl['month'] = df_pp_gl['date'].dt.month
df_pp_gl['week'] = df_pp_gl['date'].dt.week
# Out:
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Leonardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pp_gl.describe()
# Out:
#          price_paid
# count  4.090100e+04
# mean   7.913121e+05
# std    3.034220e+06
# min    1.000000e+02
# 25%    3.400000e+05
# 50%    4.650000e+05
# 75%    6.910000e+05
# max    2.409635e+08

# %%
fig, ax = plt.subplots(figsize = (25,10))
ax = sns.lineplot(data=df_pp_gl[(df_pp_gl['price_paid']<6.910000e+05) & (df_pp_gl['district'] == "CITY OF LONDON")], x="date", y="price_paid", ax=ax)
plt.setp(ax.get_xticklabels(), rotation=90)
# sns.lineplot(data=df_gl, x="date", y="parks_percent_change_from_baseline", ax=ax)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df_pp_gl
# Out:
#                                             ID  price_paid       date  \
# 231     {9FF0D969-D389-11ED-E053-6C04A8C06383}      580000 2020-01-14
# 255     {9FF0D969-D3A2-11ED-E053-6C04A8C06383}      480000 2020-01-17
# 276     {9FF0D969-D626-11ED-E053-6C04A8C06383}      315000 2020-02-14
# 287     {9FF0D969-D633-11ED-E053-6C04A8C06383}      565000 2020-02-10
# 564     {9FF0D969-D3B9-11ED-E053-6C04A8C06383}      454000 2020-01-21
# ...                                        ...         ...        ...
# 377001  {9FF0D969-D331-11ED-E053-6C04A8C06383}      342000 2020-01-24
# 377031  {9FF0D969-D5C0-11ED-E053-6C04A8C06383}      328850 2020-02-03
# 377127  {9FF0D969-D34F-11ED-E053-6C04A8C06383}      335000 2020-02-14
# 377256  {9FF0D969-D372-11ED-E053-6C04A8C06383}      480000 2020-02-07
# 377264  {9FF0D969-D37D-11ED-E053-6C04A8C06383}      480000 2020-01-29
#
#        post_code  D  N  F street_n unknown              street    locality  \
# 231      DA7 5PB  D  N  F       10     NaN           LYDD ROAD         NaN
# 255      BR6 9QX  S  N  F       11     NaN       SHELLEY CLOSE         NaN
# 276      DA5 3BE  T  N  F       72     NaN       HOWARD AVENUE         NaN
# 287      BR2 8BL  S  N  F       42     NaN    OXHAWTH CRESCENT         NaN
# 564      BR6 9BJ  S  N  F       17     NaN   WILMINGTON AVENUE         NaN
# ...          ... .. .. ..      ...     ...                 ...         ...
# 377001  DA16 2DA  T  N  F      117     NaN       RADNOR AVENUE         NaN
# 377031  DA15 8PE  S  N  F      924     NaN  EAST ROCHESTER WAY         NaN
# 377127   DA8 1DU  S  N  F      116     NaN        CARLTON ROAD         NaN
# 377256   BR3 3JP  S  N  F       23     NaN      CROSSWAYS ROAD         NaN
# 377264   BR5 1DP  S  N  F       27     NaN      EYNSFORD CLOSE  PETTS WOOD
#
#                city district          county  A  B  month  week
# 231     BEXLEYHEATH   BEXLEY  GREATER LONDON  A  A      1     3
# 255       ORPINGTON  BROMLEY  GREATER LONDON  A  A      1     3
# 276          BEXLEY   BEXLEY  GREATER LONDON  B  A      2     7
# 287         BROMLEY  BROMLEY  GREATER LONDON  A  A      2     7
# 564       ORPINGTON  BROMLEY  GREATER LONDON  A  A      1     4
# ...             ...      ...             ... .. ..    ...   ...
# 377001      WELLING   BEXLEY  GREATER LONDON  A  A      1     4
# 377031       SIDCUP   BEXLEY  GREATER LONDON  A  A      2     6
# 377127        ERITH   BEXLEY  GREATER LONDON  A  A      2     7
# 377256    BECKENHAM  BROMLEY  GREATER LONDON  A  A      2     6
# 377264    ORPINGTON  BROMLEY  GREATER LONDON  A  A      1     5
#
# [40901 rows x 18 columns]
