# %% [markdown]
# # London Air Quality Exploration

# %% [markdown]
# Enders Analysis: February 7, 2021

# %%
# import necessary libariaries
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
# change working directory to a specified directory
os.chdir('../')
print("Directory Changes")

# get current working directory
cwd = os.getcwd()
print("Current working directory is:", cwd)
# Out:
# Directory Changes
# Current working directory is: C:\Users\Carol\Documents\EndersAnalysis\project2_2.2021-3.2021

# %%
# read in air quality data for GLA 2020 and 2021
data_2020_2021 = pd.read_csv('data/processed/gl_AQ.csv')
sites_geo = pd.read_csv('data/processed/gla_codes.csv')
boroughs = gpd.read_file('data/raw/London_Borough_Excluding_MHW.shp')

# %%
data_2020_2021 = pd.merge(data_2020_2021, sites_geo, left_on="Site", right_on="code", how="left")

# %%
# gain insight into data_2020_2021
data_2020_2021.tail(25)
# Out:
#         Unnamed: 0_x Site Species   ReadingDateTime  Value   Units  \
# 288350          2282  KC1   PM2.5  14/01/2021 00:00    NaN  ug m-3
# 288351          2283  KC1   PM2.5  15/01/2021 00:00    NaN  ug m-3
# 288352          2284  KC1   PM2.5  16/01/2021 00:00    NaN  ug m-3
# 288353          2285  KC1   PM2.5  17/01/2021 00:00    NaN  ug m-3
# 288354          2286  KC1   PM2.5  18/01/2021 00:00    NaN  ug m-3
# 288355          2287  KC1   PM2.5  19/01/2021 00:00    NaN  ug m-3
# 288356          2288  KC1   PM2.5  20/01/2021 00:00    NaN  ug m-3
# 288357          2289  KC1   PM2.5  21/01/2021 00:00    NaN  ug m-3
# 288358          2290  KC1   PM2.5  22/01/2021 00:00    NaN  ug m-3
# 288359          2291  KC1   PM2.5  23/01/2021 00:00    NaN  ug m-3
# 288360          2292  KC1   PM2.5  24/01/2021 00:00    NaN  ug m-3
# 288361          2293  KC1   PM2.5  25/01/2021 00:00    NaN  ug m-3
# 288362          2294  KC1   PM2.5  26/01/2021 00:00    NaN  ug m-3
# 288363          2295  KC1   PM2.5  27/01/2021 00:00    NaN  ug m-3
# 288364          2296  KC1   PM2.5  28/01/2021 00:00    NaN  ug m-3
# 288365          2297  KC1   PM2.5  29/01/2021 00:00    NaN  ug m-3
# 288366          2298  KC1   PM2.5  30/01/2021 00:00    NaN  ug m-3
# 288367          2299  KC1   PM2.5  31/01/2021 00:00    NaN  ug m-3
# 288368          2300  KC1   PM2.5  01/02/2021 00:00    NaN  ug m-3
# 288369          2301  KC1   PM2.5  02/02/2021 00:00    NaN  ug m-3
# 288370          2302  KC1   PM2.5  03/02/2021 00:00    NaN  ug m-3
# 288371          2303  KC1   PM2.5  04/02/2021 00:00    NaN  ug m-3
# 288372          2304  KC1   PM2.5  05/02/2021 00:00    NaN  ug m-3
# 288373          2305  KC1   PM2.5  06/02/2021 00:00    NaN  ug m-3
# 288374          2306  KC1   PM2.5  07/02/2021 00:00    NaN  ug m-3
#
#        Provisional or Ratified  Unnamed: 0_y  \
# 288350                       P          93.0
# 288351                       P          93.0
# 288352                       P          93.0
# 288353                       P          93.0
# 288354                       P          93.0
# 288355                       P          93.0
# 288356                       P          93.0
# 288357                       P          93.0
# 288358                       P          93.0
# 288359                       P          93.0
# 288360                       P          93.0
# 288361                       P          93.0
# 288362                       P          93.0
# 288363                       P          93.0
# 288364                       P          93.0
# 288365                       P          93.0
# 288366                       P          93.0
# 288367                       P          93.0
# 288368                       P          93.0
# 288369                       P          93.0
# 288370                       P          93.0
# 288371                       P          93.0
# 288372                       P          93.0
# 288373                       P          93.0
# 288374                       P          93.0
#
#                                       site code   latitude  longitude  \
# 288350  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288351  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288352  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288353  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288354  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288355  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288356  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288357  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288358  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288359  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288360  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288361  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288362  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288363  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288364  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288365  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288366  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288367  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288368  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288369  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288370  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288371  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288372  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288373  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288374  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
#
#                site_type
# 288350  Urban Background
# 288351  Urban Background
# 288352  Urban Background
# 288353  Urban Background
# 288354  Urban Background
# 288355  Urban Background
# 288356  Urban Background
# 288357  Urban Background
# 288358  Urban Background
# 288359  Urban Background
# 288360  Urban Background
# 288361  Urban Background
# 288362  Urban Background
# 288363  Urban Background
# 288364  Urban Background
# 288365  Urban Background
# 288366  Urban Background
# 288367  Urban Background
# 288368  Urban Background
# 288369  Urban Background
# 288370  Urban Background
# 288371  Urban Background
# 288372  Urban Background
# 288373  Urban Background
# 288374  Urban Background

# %%
pd.to_datetime(data_2020_2021.ReadingDateTime).max()

# %%
# gain insight into data_2020_2021
sns.scatterplot(data = data_2020_2021, x = 'latitude', y = 'longitude')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
# find the unique codes (air quality monitors across GLA) in the dataset
code_list = data_2020_2021['code'].unique()
len(code_list)
# Out:
# 125

# %%
data_2020_2021['Species'][data_2020_2021['Species']=="FINE"] = "PM2.5"
# Out:
# C:\Users\Carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# find the unique types of pollutants in the dataset
pollutant_list = data_2020_2021['Species'].unique()
len(pollutant_list)
# Out:
# 2

# %%
# plan
# code: 11 different codes 
# pollutant: types of pollutant, 15 different types
# date: 24 time stamps per day, need to take an average for the pollutant type for these values to get a daily average for each reading per code

# remove NA values from 'value'
# create new column with date, no time called "new_date"
# collapse on 'code', 'new_data', and 'pollutant' to get average of value (i.e. group_by code, new_date, and pollutant (take mean of value in the process) )

# %%
# gain insight into data_2020_2021
data_2020_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288375 entries, 0 to 288374
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0_x             288375 non-null  int64
#  1   Site                     288375 non-null  object
#  2   Species                  288375 non-null  object
#  3   ReadingDateTime          288375 non-null  object
#  4   Value                    99446 non-null   float64
#  5   Units                    288375 non-null  object
#  6   Provisional or Ratified  288375 non-null  object
#  7   Unnamed: 0_y             286068 non-null  float64
#  8   site                     286068 non-null  object
#  9   code                     286068 non-null  object
#  10  latitude                 279147 non-null  float64
#  11  longitude                279147 non-null  float64
#  12  site_type                286068 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 30.8+ MB

# %% [markdown]
# ## 1) GLA Borough Analysis

# %%
# keep rows only where 'value' is not NA
boroughs.NAME = boroughs.NAME.str.replace('Westminster', 'City of Westminster')

# %%
boroughs = boroughs.to_crs("EPSG:4326")

# %%
boroughs.plot()
# Out:
# <AxesSubplot:>

# %%
data_2020_2021_gdf = gpd.GeoDataFrame(data_2020_2021, geometry=gpd.points_from_xy(data_2020_2021.longitude, data_2020_2021.latitude), crs=boroughs.crs)

# %%
data_2020_2021_gdf.crs
# Out:
# 'EPSG:4326'

# %%
boroughs_AQ = gpd.sjoin(data_2020_2021_gdf, boroughs)
boroughs_AQ = boroughs_AQ.groupby(['Species', 'GSS_CODE', 'ReadingDateTime']).mean()[['Value']].reset_index()
# Out:
# C:\Users\Carol\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)

# %%
boroughs_AQ
# Out:
#       Species   GSS_CODE ReadingDateTime      Value
# 0         NO2  E09000001      2019-01-01  32.300000
# 1         NO2  E09000001      2020-01-01  55.050000
# 2         NO2  E09000001      2021-01-01  28.450000
# 3         NO2  E09000001      2019-02-01  58.150000
# 4         NO2  E09000001      2020-02-01  26.850000
# ...       ...        ...             ...        ...
# 43059   PM2.5  E09000033      2020-08-31   7.000000
# 43060   PM2.5  E09000033      2019-10-31  28.650000
# 43061   PM2.5  E09000033      2020-10-31   9.500000
# 43062   PM2.5  E09000033      2019-12-31  20.900000
# 43063   PM2.5  E09000033      2020-12-31  16.366667
#
# [43064 rows x 4 columns]

# %%
boroughs_AQ['ReadingDateTime'] = pd.to_datetime(boroughs_AQ['ReadingDateTime'], format='%d/%m/%Y %H:%M')

# %%
boroughs_AQ.to_json('data/processed/AQ_boroughs.json')

# %%
boroughs_AQ_long = boroughs_AQ.pivot_table(index=["GSS_CODE","ReadingDateTime"], columns="Species", values="Value").reset_index()

# %%
boroughs_AQ_long
# Out:
# Species   GSS_CODE ReadingDateTime    NO2      PM2.5
# 0        E09000001      2019-01-01  32.30   7.000000
# 1        E09000001      2019-01-02  22.90   7.500000
# 2        E09000001      2019-01-03  31.00   9.000000
# 3        E09000001      2019-01-04  65.40  20.500000
# 4        E09000001      2019-01-05  57.00  17.000000
# ...            ...             ...    ...        ...
# 21062    E09000033      2021-02-03  37.34   8.866667
# 21063    E09000033      2021-02-04  41.29   7.933333
# 21064    E09000033      2021-02-05  34.50   6.800000
# 21065    E09000033      2021-02-06  29.71  10.800000
# 21066    E09000033      2021-02-07  12.16   8.300000
#
# [21067 rows x 4 columns]

# %%
for metric in list(boroughs_AQ_long.columns[2:].values):
    boroughs_AQ_long[f'SMA_3_{metric}'] = np.NaN
    boroughs_AQ_long[f'SMA_7_{metric}'] = np.NaN
    boroughs_AQ_long[f'SMA_10_{metric}'] = np.NaN
    boroughs_AQ_long[f'SMA_30_{metric}'] = np.NaN
    boroughs_AQ_long[f'SMA_45_{metric}'] = np.NaN
    
    for code in boroughs_AQ_long['GSS_CODE'].unique():
        # Calculate rolling averages for each borough
        boroughs_AQ_long[f'SMA_3_{metric}'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long[metric][boroughs_AQ_long['GSS_CODE']==code].rolling(window=3).mean()
#     gla_total_long[f'SMA_5_{metric}'] = gla_total_long[metric].rolling(window=5).mean()
        boroughs_AQ_long[f'SMA_7_{metric}'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long[metric][boroughs_AQ_long['GSS_CODE']==code].rolling(window=7).mean()
        boroughs_AQ_long[f'SMA_10_{metric}'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long[metric][boroughs_AQ_long['GSS_CODE']==code].rolling(window=10).mean()
#     gla_total_long[f'SMA_20_{metric}'] = gla_total_long[metric].rolling(window=20).mean()
        boroughs_AQ_long[f'SMA_30_{metric}'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long[metric][boroughs_AQ_long['GSS_CODE']==code].rolling(window=30).mean()
        boroughs_AQ_long[f'SMA_45_{metric}'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long[metric][boroughs_AQ_long['GSS_CODE']==code].rolling(window=45).mean()

# calculate change from baseline for each code
boroughs_AQ_long['NO2_pc_change_from_baseline'] = np.NaN
boroughs_AQ_long['PM25_pc_change_from_baseline'] = np.NaN

for code in boroughs_AQ_long['GSS_CODE'].unique():
    boroughs_AQ_long['NO2_pc_change_from_baseline'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long['SMA_30_NO2'].pct_change(365, fill_method='pad').mul(100)
    boroughs_AQ_long['PM25_pc_change_from_baseline'][boroughs_AQ_long['GSS_CODE']==code] = boroughs_AQ_long['SMA_30_PM2.5'].pct_change(365, fill_method='pad').mul(100)

# final score
boroughs_AQ_long['AQindex_pc_change_from_baseline'] = (boroughs_AQ_long['PM25_pc_change_from_baseline'] + boroughs_AQ_long['NO2_pc_change_from_baseline'])/2

# %%
boroughs_AQ_long
# Out:
# Species   GSS_CODE ReadingDateTime    NO2      PM2.5  SMA_3_NO2  SMA_7_NO2  \
# 0        E09000001      2019-01-01  32.30   7.000000        NaN        NaN
# 1        E09000001      2019-01-02  22.90   7.500000        NaN        NaN
# 2        E09000001      2019-01-03  31.00   9.000000  28.733333        NaN
# 3        E09000001      2019-01-04  65.40  20.500000  39.766667        NaN
# 4        E09000001      2019-01-05  57.00  17.000000  51.133333        NaN
# ...            ...             ...    ...        ...        ...        ...
# 21062    E09000033      2021-02-03  37.34   8.866667  33.205926  30.308254
# 21063    E09000033      2021-02-04  41.29   7.933333  36.295185  31.888254
# 21064    E09000033      2021-02-05  34.50   6.800000  37.710000  32.768254
# 21065    E09000033      2021-02-06  29.71  10.800000  35.166667  33.482540
# 21066    E09000033      2021-02-07  12.16   8.300000  25.456667  31.039683
#
# Species  SMA_10_NO2  SMA_30_NO2  SMA_45_NO2  SMA_3_PM2.5  SMA_7_PM2.5  \
# 0               NaN         NaN         NaN          NaN          NaN
# 1               NaN         NaN         NaN          NaN          NaN
# 2               NaN         NaN         NaN     7.833333          NaN
# 3               NaN         NaN         NaN    12.333333          NaN
# 4               NaN         NaN         NaN    15.500000          NaN
# ...             ...         ...         ...          ...          ...
# 21062     34.270778   34.129114   31.750922    11.772222     9.435714
# 21063     33.845778   34.802114   32.176533     9.316667     9.645238
# 21064     33.071778   35.017352   32.133477     7.866667     9.588095
# 21065     31.765778   34.535185   32.196199     8.511111    10.102381
# 21066     29.958778   33.441769   32.122224     8.633333     9.878571
#
# Species  SMA_10_PM2.5  SMA_30_PM2.5  SMA_45_PM2.5  \
# 0                 NaN           NaN           NaN
# 1                 NaN           NaN           NaN
# 2                 NaN           NaN           NaN
# 3                 NaN           NaN           NaN
# 4                 NaN           NaN           NaN
# ...               ...           ...           ...
# 21062        9.775000     10.886667     10.495556
# 21063        9.398333     10.964444     10.571852
# 21064        9.128333     10.957778     10.489630
# 21065        9.158333     10.617778     10.596296
# 21066        9.341667     10.096667     10.681852
#
# Species  NO2_pc_change_from_baseline  PM25_pc_change_from_baseline  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 21062                     -28.861932                    -20.757006
# 21063                     -28.716586                    -20.190869
# 21064                     -29.719510                    -20.239395
# 21065                     -30.987332                    -22.714222
# 21066                     -33.051436                    -26.507340
#
# Species  AQindex_pc_change_from_baseline
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 21062                         -24.809469
# 21063                         -24.453728
# 21064                         -24.979452
# 21065                         -26.850777
# 21066                         -29.779388
#
# [21067 rows x 17 columns]

# %%
boroughs_AQ_long.to_csv('data/processed_final/AQ_boroughs.csv')

# %% [markdown]
# ## 2) GLA Analysis

# %%
data_2020_2021
# Out:
#         Unnamed: 0_x Site Species   ReadingDateTime  Value   Units  \
# 0                  0  BG1     NO2  01/01/2019 00:00    NaN  ug m-3
# 1                  1  BG1     NO2  02/01/2019 00:00    NaN  ug m-3
# 2                  2  BG1     NO2  03/01/2019 00:00    NaN  ug m-3
# 3                  3  BG1     NO2  04/01/2019 00:00    NaN  ug m-3
# 4                  4  BG1     NO2  05/01/2019 00:00    NaN  ug m-3
# ...              ...  ...     ...               ...    ...     ...
# 288370          2302  KC1   PM2.5  03/02/2021 00:00    NaN  ug m-3
# 288371          2303  KC1   PM2.5  04/02/2021 00:00    NaN  ug m-3
# 288372          2304  KC1   PM2.5  05/02/2021 00:00    NaN  ug m-3
# 288373          2305  KC1   PM2.5  06/02/2021 00:00    NaN  ug m-3
# 288374          2306  KC1   PM2.5  07/02/2021 00:00    NaN  ug m-3
#
#        Provisional or Ratified  Unnamed: 0_y  \
# 0                            R          20.0
# 1                            R          20.0
# 2                            R          20.0
# 3                            R          20.0
# 4                            R          20.0
# ...                        ...           ...
# 288370                       P          93.0
# 288371                       P          93.0
# 288372                       P          93.0
# 288373                       P          93.0
# 288374                       P          93.0
#
#                                       site code   latitude  longitude  \
# 0        Barking and Dagenham - Rush Green  BG1  51.563752   0.177891
# 1        Barking and Dagenham - Rush Green  BG1  51.563752   0.177891
# 2        Barking and Dagenham - Rush Green  BG1  51.563752   0.177891
# 3        Barking and Dagenham - Rush Green  BG1  51.563752   0.177891
# 4        Barking and Dagenham - Rush Green  BG1  51.563752   0.177891
# ...                                    ...  ...        ...        ...
# 288370  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288371  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288372  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288373  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
# 288374  Kensington and Chelsea - North Ken  KC1  51.521047  -0.213492
#
#                site_type
# 0               Suburban
# 1               Suburban
# 2               Suburban
# 3               Suburban
# 4               Suburban
# ...                  ...
# 288370  Urban Background
# 288371  Urban Background
# 288372  Urban Background
# 288373  Urban Background
# 288374  Urban Background
#
# [288375 rows x 13 columns]

# %%
# make new variable, gla_total, by using group_by on data_2020_2021 to group by 'new_date', and 'pollutant', taking the mean of 'value', and ignoring 'code', 'latitude', and 'longitude'
gla_total = data_2020_2021[data_2020_2021['Value'].notna()] 
gla_total = gla_total.groupby(['ReadingDateTime', 'Species'], as_index=False)['Value'].mean()
gla_total
# Out:
#        ReadingDateTime Species      Value
# 0     01/01/2019 00:00     NO2  26.845745
# 1     01/01/2019 00:00   PM2.5   7.381250
# 2     01/01/2020 00:00     NO2  44.531633
# 3     01/01/2020 00:00   PM2.5  31.903030
# 4     01/01/2021 00:00     NO2  28.920619
# ...                ...     ...        ...
# 1533  31/10/2020 00:00   PM2.5   7.479070
# 1534  31/12/2019 00:00     NO2  39.546078
# 1535  31/12/2019 00:00   PM2.5  20.084375
# 1536  31/12/2020 00:00     NO2  37.632292
# 1537  31/12/2020 00:00   PM2.5  16.652381
#
# [1538 rows x 3 columns]

# %%
gla_total[gla_total['Species']=='NO2'].sort_values('ReadingDateTime').tail()
# Out:
#        ReadingDateTime Species      Value
# 1528  31/08/2020 00:00     NO2  29.867742
# 1530  31/10/2019 00:00     NO2  46.791667
# 1532  31/10/2020 00:00     NO2  18.131633
# 1534  31/12/2019 00:00     NO2  39.546078
# 1536  31/12/2020 00:00     NO2  37.632292

# %%
pollutant_list = list(np.unique(gla_total['Species']))
pollutant_list
# Out:
# ['NO2', 'PM2.5']

# %%
# convert 'date_new' to date-time object
gla_total['ReadingDateTime'] = pd.to_datetime(gla_total['ReadingDateTime'], format='%d/%m/%Y %H:%M')
gla_total[gla_total['Species']=='NO2'].sort_values('ReadingDateTime').tail()
# Out:
#     ReadingDateTime Species      Value
# 114      2021-02-03     NO2  36.734694
# 166      2021-02-04     NO2  37.865979
# 218      2021-02-05     NO2  35.370103
# 270      2021-02-06     NO2  30.094949
# 322      2021-02-07     NO2  10.031633

# %%
# remove weekends
# gla_total = gla_total[gla_total['ReadingDateTime'].dt.weekday < 5]

# %%
gla_total.head()
# Out:
#   ReadingDateTime Species      Value
# 0      2019-01-01     NO2  26.845745
# 1      2019-01-01   PM2.5   7.381250
# 2      2020-01-01     NO2  44.531633
# 3      2020-01-01   PM2.5  31.903030
# 4      2021-01-01     NO2  28.920619

# %%
gla_total['ReadingDateTime'][gla_total['Species']=='NO2']
# Out:
# 0      2019-01-01
# 2      2020-01-01
# 4      2021-01-01
# 6      2019-02-01
# 8      2020-02-01
#           ...
# 1528   2020-08-31
# 1530   2019-10-31
# 1532   2020-10-31
# 1534   2019-12-31
# 1536   2020-12-31
# Name: ReadingDateTime, Length: 769, dtype: datetime64[ns]

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# NO2
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total.sort_values('ReadingDateTime')['ReadingDateTime'][gla_total['Species']=='NO2'],
        gla_total.sort_values('ReadingDateTime')['Value'][gla_total['Species']=='NO2'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Average NO2 Levels",
       title="Average NO2 Levels in the Greater London Area: 2020-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# air_temp
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total.sort_values('ReadingDateTime')['ReadingDateTime'][gla_total['Species']=='PM2.5'],
        gla_total.sort_values('ReadingDateTime')['Value'][gla_total['Species']=='PM2.5'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Average PM2.5 Levels",
       title="Average PM2.5 Levels in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# pivot data for rolling average
gla_total_long = gla_total.pivot(index="ReadingDateTime", columns="Species", values="Value")

# %%
gla_total_long
# Out:
# Species                NO2      PM2.5
# ReadingDateTime
# 2019-01-01       26.845745   7.381250
# 2019-01-02       39.938710   7.453125
# 2019-01-03       50.572340  10.084848
# 2019-01-04       58.429787  21.360606
# 2019-01-05       46.007368  17.621212
# ...                    ...        ...
# 2021-02-03       36.734694   8.185366
# 2021-02-04       37.865979   7.711905
# 2021-02-05       35.370103   6.326829
# 2021-02-06       30.094949  10.174419
# 2021-02-07       10.031633   7.447619
#
# [769 rows x 2 columns]

# %%
for metric in list(gla_total_long.columns.values):
    gla_total_long[f'SMA_3_{metric}'] = gla_total_long[metric].rolling(window=3).mean()
    gla_total_long[f'SMA_5_{metric}'] = gla_total_long[metric].rolling(window=5).mean()
    gla_total_long[f'SMA_7_{metric}'] = gla_total_long[metric].rolling(window=7).mean()
    gla_total_long[f'SMA_10_{metric}'] = gla_total_long[metric].rolling(window=10).mean()
    gla_total_long[f'SMA_20_{metric}'] = gla_total_long[metric].rolling(window=20).mean()
    gla_total_long[f'SMA_30_{metric}'] = gla_total_long[metric].rolling(window=30).mean()
    gla_total_long[f'SMA_45_{metric}'] = gla_total_long[metric].rolling(window=45).mean()

# %%
gla_total_long
# Out:
# Species                NO2      PM2.5  SMA_3_NO2  SMA_5_NO2  SMA_7_NO2  \
# ReadingDateTime
# 2019-01-01       26.845745   7.381250        NaN        NaN        NaN
# 2019-01-02       39.938710   7.453125        NaN        NaN        NaN
# 2019-01-03       50.572340  10.084848  39.118932        NaN        NaN
# 2019-01-04       58.429787  21.360606  49.646946        NaN        NaN
# 2019-01-05       46.007368  17.621212  51.669832  44.358790        NaN
# ...                    ...        ...        ...        ...        ...
# 2021-02-03       36.734694   8.185366  31.962560  28.588761  28.089803
# 2021-02-04       37.865979   7.711905  33.720292  31.836651  29.684514
# 2021-02-05       35.370103   6.326829  36.656925  33.824753  30.882841
# 2021-02-06       30.094949  10.174419  34.443677  33.325186  32.092615
# 2021-02-07       10.031633   7.447619  25.165562  30.019472  29.892907
#
# Species          SMA_10_NO2  SMA_20_NO2  SMA_30_NO2  SMA_45_NO2  SMA_3_PM2.5  \
# ReadingDateTime
# 2019-01-01              NaN         NaN         NaN         NaN          NaN
# 2019-01-02              NaN         NaN         NaN         NaN          NaN
# 2019-01-03              NaN         NaN         NaN         NaN     8.306408
# 2019-01-04              NaN         NaN         NaN         NaN    12.966193
# 2019-01-05              NaN         NaN         NaN         NaN    16.355556
# ...                     ...         ...         ...         ...          ...
# 2021-02-03        32.622813   31.603434   32.584447   32.584447    11.010549
# 2021-02-04        32.019819   31.293575   33.192317   33.192317     8.698257
# 2021-02-05        31.141981   31.501410   33.462252   33.462252     7.408033
# 2021-02-06        29.995965   31.696776   33.071943   33.071943     8.071051
# 2021-02-07        28.328829   30.548564   32.018296   32.018296     7.982956
#
# Species          SMA_5_PM2.5  SMA_7_PM2.5  SMA_10_PM2.5  SMA_20_PM2.5  \
# ReadingDateTime
# 2019-01-01               NaN          NaN           NaN           NaN
# 2019-01-02               NaN          NaN           NaN           NaN
# 2019-01-03               NaN          NaN           NaN           NaN
# 2019-01-04               NaN          NaN           NaN           NaN
# 2019-01-05         12.780208          NaN           NaN           NaN
# ...                      ...          ...           ...           ...
# 2021-02-03          9.830627     8.710303      8.826508      8.406345
# 2021-02-04         10.049198     9.055209      8.595198      7.945401
# 2021-02-05          9.414076     9.027410      8.440822      7.860559
# 2021-02-06          8.519204     9.535320      8.518528      7.972701
# 2021-02-07          7.969228     9.241774      8.733533      8.020637
#
# Species          SMA_30_PM2.5  SMA_45_PM2.5
# ReadingDateTime
# 2019-01-01                NaN           NaN
# 2019-01-02                NaN           NaN
# 2019-01-03                NaN           NaN
# 2019-01-04                NaN           NaN
# 2019-01-05                NaN           NaN
# ...                       ...           ...
# 2021-02-03           9.323675      9.323675
# 2021-02-04           9.434316      9.434316
# 2021-02-05           9.437487      9.437487
# 2021-02-06           9.209634      9.209634
# 2021-02-07           8.766948      8.766948
#
# [769 rows x 16 columns]

# %%
## SELECT ROLLING WINDOW
window = "45"

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# NO2
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total_long.index,
        gla_total_long[f'SMA_{window}_NO2'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="3 day moving Average NO2",
       title="Average NO2 in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# PM2.5
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total_long.index,
        gla_total_long[f'SMA_{window}_PM2.5'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="3 day moving Average PM2.5",
       title="Average PM2.5 in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
gla_total_long = gla_total_long.reset_index()

# %%
gla_total_long['NO2_pc_change_from_baseline'] = gla_total_long['SMA_30_NO2'].pct_change(365, fill_method='pad').mul(100)
gla_total_long['PM25_pc_change_from_baseline'] = gla_total_long['SMA_30_PM2.5'].pct_change(365, fill_method='pad').mul(100)
gla_total_long['AQindex_pc_change_from_baseline'] = (gla_total_long['PM25_pc_change_from_baseline'] + gla_total_long['NO2_pc_change_from_baseline'])/2

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# PM2.5
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total_long.ReadingDateTime,
        gla_total_long['NO2_pc_change_from_baseline'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="3 day moving Average NO2",
       title="Average NO2 in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# PM2.5
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total_long.ReadingDateTime,
        gla_total_long['PM25_pc_change_from_baseline'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="3 day moving Average PM2.5",
       title="Average PM2.5 in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
# plot each 'value' of each 'pollutant' type seperately over time (i.e. over 'new_date')
# PM2.5
# create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# add x-axis and y-axis
ax.plot(gla_total_long.ReadingDateTime,
        gla_total_long['AQindex_pc_change_from_baseline'],
        color='purple')

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="3 day moving Average AQ Index",
       title="Average AQ Index in the Greater London Area: 2019-2021")

# rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
gla_total_long.to_csv('data/processed_final/AQ_gla.csv')

# %%
data_grouped.plot(x = 'latitude', y = 'longitude')
# Out:
# <AxesSubplot:xlabel='latitude'>

# %%
data_grouped = data_grouped[(data_grouped['latitude']<55) & (data_grouped['longitude']> -0.5) ]

# %%
# remove points that do not fall within the GLA boundary
data_grouped['latitude'].max()
# Out:
# 55.945589

# %%
data_grouped.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-1d03e4964da4> in <module>
# ----> 1 data_grouped.head
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'

# %%
data_grouped = data_grouped[(data_grouped['latitude']<55) & (data_grouped['longitude']> -0.5) ]
